# %%
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime

# %%
def DisplayGraphWithInfos(array, infos, title, axs, axy, axn, fig):
    x_lims = list()
    x_lims.append(infos[0]+datetime.timedelta(hours=16))
    x_lims.append(x_lims[0]+datetime.timedelta(days=infos[7]))
    x_lims = mdates.date2num(x_lims)
    axs[axy][axn].xaxis_date()
    axs[axy][axn].imshow(array, origin='lower', cmap=plt.get_cmap('jet',20) , aspect='auto',extent=[x_lims[0],x_lims[1],infos[2],infos[1]])
    
    if axn == 0:
        stationsNameAxis = axs[axy][axn].twinx()
        stationsNameAxis.set_yticks(np.arange(len(infos[10])), minor=False)
        stationsNameAxis.set_yticklabels(infos[10],fontdict=None, minor=False)
    
    x_lims = mdates.DateFormatter("%H:%M")
    axs[axy][axn].xaxis.set_major_formatter(x_lims)
    axs[axy][axn].set_title("{} -- {} -- {}/{}/{} -- Quiet:{}".format(infos[9], title, infos[0].year, infos[0].month, infos[0].day, infos[8]))
    axs[axy][axn].set_xlabel("Time")
    axs[axy][axn].set_ylabel("Latitude")
    sm = plt.cm.ScalarMappable(cmap=plt.get_cmap('jet',20), norm=plt.Normalize(vmin=infos[6], vmax=infos[5]))
    sm._A = []
    clb=fig.colorbar(sm, ax=axs[axy][axn])
    clb.set_label("nT")

# %%
epoch = 5
localFileName = "../TrainingDataset/x_train/"
localFileNameASIA = "../TrainingDataset/Asia/x_train/"
localFileNameAmerica = "../TrainingDataset/America/Dataset/"
mountFileName = '../../Bureau/IRAP_mount/TrainingDataset/x_train/'
numberOfPlots = 5
trainingArray = np.array([])
fig, axs = plt.subplots(numberOfPlots,3, figsize=(25, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.1)

axs = axs.ravel().reshape(numberOfPlots,3)
fig.set_size_inches(40,numberOfPlots*5)

for i in range(numberOfPlots):
    trainingArray = np.load('{}y2_{}.npy'.format(localFileNameASIA, epoch+i), allow_pickle=True, encoding="latin1")
    DisplayGraphWithInfos(trainingArray[3], trainingArray[2], "Ground truth", axs, i, 0, fig)
    DisplayGraphWithInfos(trainingArray[0], trainingArray[2], "Ground truth with VC", axs, i, 1, fig)
    DisplayGraphWithInfos(trainingArray[1], trainingArray[2], "Ground truth with ML", axs, i, 2, fig)

if trainingArray[2][11][0] != 'custom':
    fig.suptitle('{} showcasing plots of the {} component above {}'.format(numberOfPlots, trainingArray[2][9], trainingArray[2][11][0]), fontsize=48)
    fig.show()
    fig.savefig("DisplayDataset_{}.png".format(trainingArray[2][11][0]))
else:
    fig.suptitle('{} showcasing plots of the {} component above {}'.format(numberOfPlots, trainingArray[2][9], trainingArray[2][11][1]), fontsize=48)
    fig.show()
    fig.savefig("DisplayDataset_{}.png".format(trainingArray[2][11][1]))
